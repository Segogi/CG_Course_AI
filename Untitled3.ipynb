# %%
# !git init
# !git config --global user.name "Segogi"
# !git config --global user.email "sergomgil@gmail.com"
# !git add .
# !git commit -m "initialize project"
# !git branch -M main
# !git remote add origin https://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@github.com/Segogi/CG_Course_AI.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/.git/
# On branch master
# nothing to commit, working tree clean
# Enumerating objects: 28, done.
# Counting objects: 100% (28/28), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (21/21), done.
# Writing objects: 100% (28/28), 8.42 MiB | 2.25 MiB/s, done.
# Total 28 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), done.
# To https://github.com/Segogi/CG_Course_AI.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
